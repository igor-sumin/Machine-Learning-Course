# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')
pd.options.mode.chained_assignment = None

# %%
weight = 'weight_kg'
pos = 'player_positions'
limit_val = 0.9

# %%
data = pd.read_csv("players_20.csv", index_col=2)
data
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# Xiao Mingjie       https://sofifa.com/player/250995/mingjie-xiao/...
# Zhang Wei          https://sofifa.com/player/252332/wei-zhang/20/...
# Wang Haijian       https://sofifa.com/player/251110/haijian-wang/...
# Pan Ximing         https://sofifa.com/player/233449/ximing-pan/20...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# J. Oblak                 188         87    Slovenia
# E. Hazard                175         74     Belgium
# ...                      ...        ...         ...
# Shao Shuai               186         79    China PR
# Xiao Mingjie             177         66    China PR
# Zhang Wei                186         75    China PR
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club  overall  ...   lwb   ldm  \
# short_name                                                 ...
# L. Messi                            FC Barcelona       94  ...  68+2  66+2
# Cristiano Ronaldo                       Juventus       93  ...  65+3  61+3
# Neymar Jr                    Paris Saint-Germain       92  ...  66+3  61+3
# J. Oblak                         Atlético Madrid       91  ...   NaN   NaN
# E. Hazard                            Real Madrid       91  ...  66+3  63+3
# ...                                          ...      ...  ...   ...   ...
# Shao Shuai                      Beijing Renhe FC       48  ...  43+2  42+2
# Xiao Mingjie                    Shanghai SIPG FC       48  ...  44+2  43+2
# Zhang Wei                 Hebei China Fortune FC       48  ...  47+2  49+2
# Wang Haijian       Shanghai Greenland Shenhua FC       48  ...  48+2  48+2
# Pan Ximing                Hebei China Fortune FC       48  ...  48+2  49+2
#
#                     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# short_name
# L. Messi           66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# Cristiano Ronaldo  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# Neymar Jr          61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# J. Oblak            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# E. Hazard          63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
# ...                 ...   ...   ...   ...   ...   ...   ...   ...
# Shao Shuai         42+2  42+2  43+2  45+2  46+2  46+2  46+2  45+2
# Xiao Mingjie       43+2  43+2  44+2  46+2  47+2  47+2  47+2  46+2
# Zhang Wei          49+2  49+2  47+2  47+2  49+2  49+2  49+2  47+2
# Wang Haijian       48+2  48+2  48+2  48+2  49+2  49+2  49+2  48+2
# Pan Ximing         49+2  49+2  48+2  48+2  50+2  50+2  50+2  48+2
#
# [18278 rows x 103 columns]

# %% [markdown]
# ### Задача
# Нужно выполнить классификацию признака "player_positions", которая является позицией игроков в fifa 20 на футбольном поле

# %%
data[pos].head()
# Out:
# short_name
# L. Messi             RW, CF, ST
# Cristiano Ronaldo        ST, LW
# Neymar Jr               LW, CAM
# J. Oblak                     GK
# E. Hazard                LW, CF
# Name: player_positions, dtype: object

# %% [markdown]
# ### Описание данных
# Данные представляют собой игровые характеристики футболистов в fifa 20.
# Опишем далее наиболее важные признаки представленных в датасете игроков:
#
# | признак  | описание |
# | ------------- | ------------- |
# | long_name  | полное имя игрока  |
# | age  | возраст игрока  |
# | dob  | дата рождения  |
# | height_cm  | высота игрока в сантиметрах  |
# | weight_kg  | вес игрока в килограммах  |
# | nationality  | национальность игрока  |
# | club  | клуб за который выступает игрок  |
# | overall  | итоговая характеристика игрока (из 100 возможных пунктов) |
# | value_eur  | ценновая стоимость игрока в Евро |
# | wage_eur  | зарплата игрока в клубе |
# | player_positions  | позиция игрока на футбольном поле |
# | wage_eur  | зарплата игрока в клубе |
# | wage_eur  | зарплата игрока в клубе |
# |team_jersey_number|номер игрока|
# |joined|с какого момента игрок выступает за клуб|
# |contract_valid_until|дата окончания контракта игрока с клубом|
# |**pace, power_jumping, defending_marking, ...**|**физические характеристики игрока**|

# %% [markdown]
# ### Обработка данных
# В нашем датасете есть немало ненужных признаков, поэтому перед обработкой данных необходимо удалить признаки, не имеющие для нас никакой ценности.
# Помимо этого, мы обьединим классы в 4 суперкласса, отвечающие за 4 основные позиции на футбольном поле, а именно:
# `вратать`, `защитник`, `полузащитник`, `нападающий`

# %%
# выведем все признаки
print(data.columns.tolist())
# Out:
# ['sofifa_id', 'player_url', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']

# %%
# удалим ненужные признаки, оставив физические характеристики игрока, его имя, вес и конкретную позицию на футбольном поле
data = data.drop(['sofifa_id', 'player_url', 'long_name', 'age', 'dob', 'height_cm', \
                  'nationality', 'club', 'overall', 'potential', 'value_eur', \
                  'wage_eur'], axis=1
                )
data = data.drop(['preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', \
                  'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', \
                  'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', \
                  'nation_position', 'nation_jersey_number', 'player_traits'], axis=1
                )
data = data.drop(['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', \
                  'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', \
                  'cb', 'rcb', 'rb'], axis=1
                )

# удалим и заполнили нулями NaN'ы
data = data[data[pos].notna()]
data = data.fillna(0)

print(data.columns.tolist())
# Out:
# ['weight_kg', 'player_positions', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']

# %%
# обьединим классы в 4 суперкласса
striker    = np.array(['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW'])
defender   = np.array(['LWB', 'LDM', 'FDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'CDM'])
midfielder = np.array(['LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM'])
goalkeeper = np.array(['GK'])

for i in range(len(data[pos])):
    player = data[pos][i].split(',')[0]
    if player in striker:
        data[pos][i] = 'striker'
    elif player in defender:
        data[pos][i] = 'defender'
    elif player in midfielder:
        data[pos][i] = 'midfielder'
    else:
        assert(player == 'GK')
        data[pos][i] = 'goalkeeper'
        
print(data[pos])
print("Количество суперклассов = ", len(data[pos].value_counts()))
print(data[pos].value_counts())
# Out:
# short_name
# L. Messi                striker
# Cristiano Ronaldo       striker
# Neymar Jr               striker
# J. Oblak             goalkeeper
# E. Hazard               striker
#                         ...
# Shao Shuai             defender
# Xiao Mingjie           defender
# Zhang Wei            midfielder
# Wang Haijian         midfielder
# Pan Ximing           midfielder
# Name: player_positions, Length: 18278, dtype: object
# Количество суперклассов =  4
# defender      7362
# midfielder    5438
# striker       3442
# goalkeeper    2036
# Name: player_positions, dtype: int64

# %%
data[pos].value_counts()
# Out:
# defender      7362
# midfielder    5438
# striker       3442
# goalkeeper    2036
# Name: player_positions, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18278 entries, L. Messi to Pan Ximing
# Data columns (total 48 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   weight_kg                   18278 non-null  int64
#  1   player_positions            18278 non-null  object
#  2   pace                        18278 non-null  float64
#  3   shooting                    18278 non-null  float64
#  4   passing                     18278 non-null  float64
#  5   dribbling                   18278 non-null  float64
#  6   defending                   18278 non-null  float64
#  7   physic                      18278 non-null  float64
#  8   gk_diving                   18278 non-null  float64
#  9   gk_handling                 18278 non-null  float64
#  10  gk_kicking                  18278 non-null  float64
#  11  gk_reflexes                 18278 non-null  float64
#  12  gk_speed                    18278 non-null  float64
#  13  gk_positioning              18278 non-null  float64
#  14  attacking_crossing          18278 non-null  int64
#  15  attacking_finishing         18278 non-null  int64
#  16  attacking_heading_accuracy  18278 non-null  int64
#  17  attacking_short_passing     18278 non-null  int64
#  18  attacking_volleys           18278 non-null  int64
#  19  skill_dribbling             18278 non-null  int64
#  20  skill_curve                 18278 non-null  int64
#  21  skill_fk_accuracy           18278 non-null  int64
#  22  skill_long_passing          18278 non-null  int64
#  23  skill_ball_control          18278 non-null  int64
#  24  movement_acceleration       18278 non-null  int64
#  25  movement_sprint_speed       18278 non-null  int64
#  26  movement_agility            18278 non-null  int64
#  27  movement_reactions          18278 non-null  int64
#  28  movement_balance            18278 non-null  int64
#  29  power_shot_power            18278 non-null  int64
#  30  power_jumping               18278 non-null  int64
#  31  power_stamina               18278 non-null  int64
#  32  power_strength              18278 non-null  int64
#  33  power_long_shots            18278 non-null  int64
#  34  mentality_aggression        18278 non-null  int64
#  35  mentality_interceptions     18278 non-null  int64
#  36  mentality_positioning       18278 non-null  int64
#  37  mentality_vision            18278 non-null  int64
#  38  mentality_penalties         18278 non-null  int64
#  39  mentality_composure         18278 non-null  int64
#  40  defending_marking           18278 non-null  int64
#  41  defending_standing_tackle   18278 non-null  int64
#  42  defending_sliding_tackle    18278 non-null  int64
#  43  goalkeeping_diving          18278 non-null  int64
#  44  goalkeeping_handling        18278 non-null  int64
#  45  goalkeeping_kicking         18278 non-null  int64
#  46  goalkeeping_positioning     18278 non-null  int64
#  47  goalkeeping_reflexes        18278 non-null  int64
# dtypes: float64(12), int64(35), object(1)
# memory usage: 7.5+ MB

# %%
LE = preprocessing.LabelEncoder()

# %%
LE.fit(data[pos])
data[pos] = LE.transform(data[pos])

# %%
plt.scatter(data[pos], data[weight])

# %% [markdown]
# ### Работа с выбросами

# %%
data[weight]
# Out:
# short_name
# L. Messi             72
# Cristiano Ronaldo    83
# Neymar Jr            68
# J. Oblak             87
# E. Hazard            74
#                      ..
# Shao Shuai           79
# Xiao Mingjie         66
# Zhang Wei            75
# Wang Haijian         74
# Pan Ximing           78
# Name: weight_kg, Length: 18278, dtype: int64

# %%
data[weight].quantile([0.005, 0.5, 0.995])
# Out:
# 0.005    59.0
# 0.500    75.0
# 0.995    94.0
# Name: weight_kg, dtype: float64

# %%
# удалим игроков, которые выходят за пределы квантилей 0.005 и 0.995
drop_players = data[(data[weight] < data[weight].quantile(0.005)) |
                    (data[weight] > data[weight].quantile(0.995))].index
data = data.drop(drop_players)
print(data.shape)
# Out:
# (18082, 48)

# %%
plt.scatter(data[pos], data[weight])

# %% [markdown]
# ### Визуализация данных и описательная статистика

# %%
data.describe()
# Out:
#           weight_kg  player_positions          pace      shooting  \
# count  18082.000000      18082.000000  18082.000000  18082.000000
# mean      75.250304          1.269882     60.271154     46.551930
# std        6.789531          1.176033     23.682721     21.039224
# min       59.000000          0.000000      0.000000      0.000000
# 25%       70.000000          0.000000     57.000000     35.000000
# 50%       75.000000          1.000000     67.000000     52.000000
# 75%       80.000000          2.000000     74.000000     62.000000
# max       94.000000          3.000000     96.000000     93.000000
#
#             passing     dribbling     defending        physic     gk_diving  \
# count  18082.000000  18082.000000  18082.000000  18082.000000  18082.000000
# mean      50.958190     55.665856     45.931921     57.787966      7.174704
# std       20.417254     21.823544     22.357263     22.257640     20.590550
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       46.000000     53.000000     31.000000     55.000000      0.000000
# 50%       56.000000     62.000000     53.000000     65.000000      0.000000
# 75%       64.000000     69.000000     64.000000     71.000000      0.000000
# max       92.000000     96.000000     90.000000     90.000000     90.000000
#
#         gk_handling  ...  mentality_penalties  mentality_composure  \
# count  18082.000000  ...         18082.000000         18082.000000
# mean       6.927829  ...            48.428492            58.554972
# std       19.873622  ...            15.677591            11.864461
# min        0.000000  ...             7.000000            12.000000
# 25%        0.000000  ...            39.000000            51.000000
# 50%        0.000000  ...            49.000000            60.000000
# 75%        0.000000  ...            60.000000            67.000000
# max       92.000000  ...            92.000000            96.000000
#
#        defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# count       18082.000000               18082.000000              18082.000000
# mean           46.941323                  47.740792                 45.700088
# std            20.069252                  21.558725                 21.193631
# min             1.000000                   5.000000                  3.000000
# 25%            29.000000                  27.000000                 24.000000
# 50%            52.000000                  55.000000                 52.000000
# 75%            64.000000                  66.000000                 64.000000
# max            94.000000                  92.000000                 90.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        18082.000000          18082.000000         18082.000000
# mean            16.475390             16.266066            16.124544
# std             17.606807             16.879099            16.507807
# min              1.000000              1.000000             1.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             90.000000             92.000000            93.000000
#
#        goalkeeping_positioning  goalkeeping_reflexes
# count             18082.000000          18082.000000
# mean                 16.274693             16.610275
# std                  17.006134             17.904293
# min                   1.000000              1.000000
# 25%                   8.000000              8.000000
# 50%                  11.000000             11.000000
# 75%                  14.000000             14.000000
# max                  91.000000             92.000000
#
# [8 rows x 48 columns]

# %% [markdown]
# #### Корреляция между элементами

# %%
# вычислим матрицу корреляции для количественных признаков
corr_matr = data.corr()
corr_matr
# Out:
#                             weight_kg  player_positions      pace  shooting  \
# weight_kg                    1.000000         -0.168174 -0.447721 -0.310092
# player_positions            -0.168174          1.000000  0.202009  0.486131
# pace                        -0.447721          0.202009  1.000000  0.793528
# shooting                    -0.310092          0.486131  0.793528  1.000000
# passing                     -0.366788          0.157358  0.845598  0.879776
# dribbling                   -0.413748          0.261519  0.909521  0.911048
# defending                   -0.101639         -0.483124  0.550485  0.382933
# physic                      -0.086152         -0.063533  0.779688  0.709946
# gk_diving                    0.334362         -0.079968 -0.886825 -0.771024
# gk_handling                  0.335248         -0.080001 -0.887201 -0.771351
# gk_kicking                   0.333614         -0.079931 -0.886416 -0.770668
# gk_reflexes                  0.334180         -0.079917 -0.886269 -0.770541
# gk_speed                     0.321039         -0.077217 -0.856320 -0.744502
# gk_positioning               0.336115         -0.079796 -0.884919 -0.769367
# attacking_crossing          -0.395519          0.128126  0.753902  0.766324
# attacking_finishing         -0.287946          0.628107  0.678109  0.952977
# attacking_heading_accuracy   0.046185         -0.036912  0.608888  0.628442
# attacking_short_passing     -0.285037          0.106130  0.724313  0.798563
# attacking_volleys           -0.255718          0.525705  0.655823  0.910435
# skill_dribbling             -0.410281          0.340934  0.847260  0.903737
# skill_curve                 -0.344542          0.320473  0.682914  0.838788
# skill_fk_accuracy           -0.306458          0.276961  0.589600  0.781388
# skill_long_passing          -0.254299         -0.014286  0.573185  0.657098
# skill_ball_control          -0.334768          0.256457  0.822170  0.896467
# movement_acceleration       -0.486366          0.269891  0.878433  0.651017
# movement_sprint_speed       -0.414805          0.247701  0.885494  0.642413
# movement_agility            -0.537488          0.323381  0.755087  0.683226
# movement_reactions           0.087389          0.018774  0.156293  0.365675
# movement_balance            -0.662075          0.247054  0.671849  0.575202
# power_shot_power            -0.054797          0.438315  0.368306  0.746264
# power_jumping                0.039297         -0.138741  0.216029  0.151321
# power_stamina               -0.213214         -0.040979  0.728169  0.647104
# power_strength               0.608720         -0.215911 -0.012109  0.079975
# power_long_shots            -0.275272          0.452488  0.665509  0.937608
# mentality_aggression         0.032601         -0.284022  0.467842  0.440581
# mentality_interceptions     -0.024808         -0.595307  0.346559  0.195353
# mentality_positioning       -0.351140          0.472549  0.769975  0.927364
# mentality_vision            -0.278556          0.379157  0.464159  0.712031
# mentality_penalties         -0.240796          0.477007  0.646803  0.878666
# mentality_composure         -0.052880          0.126238  0.442046  0.632141
# defending_marking           -0.044587         -0.562247  0.405720  0.244145
# defending_standing_tackle   -0.048530         -0.604224  0.383535  0.197982
# defending_sliding_tackle    -0.059735         -0.632534  0.367141  0.158974
# goalkeeping_diving           0.333798         -0.082184 -0.871413 -0.754964
# goalkeeping_handling         0.335592         -0.079739 -0.871372 -0.753297
# goalkeeping_kicking          0.332756         -0.078098 -0.868490 -0.750020
# goalkeeping_positioning      0.336227         -0.080493 -0.870095 -0.750573
# goalkeeping_reflexes         0.334653         -0.078148 -0.872499 -0.753531
#
#                              passing  dribbling  defending    physic  \
# weight_kg                  -0.366788  -0.413748  -0.101639 -0.086152
# player_positions            0.157358   0.261519  -0.483124 -0.063533
# pace                        0.845598   0.909521   0.550485  0.779688
# shooting                    0.879776   0.911048   0.382933  0.709946
# passing                     1.000000   0.962868   0.684615  0.826108
# dribbling                   0.962868   1.000000   0.595052  0.809623
# defending                   0.684615   0.595052   1.000000  0.814866
# physic                      0.826108   0.809623   0.814866  1.000000
# gk_diving                  -0.869715  -0.888840  -0.715906 -0.904729
# gk_handling                -0.870083  -0.889217  -0.716210 -0.905112
# gk_kicking                 -0.869313  -0.888430  -0.715576 -0.904311
# gk_reflexes                -0.869169  -0.888283  -0.715457 -0.904162
# gk_speed                   -0.839798  -0.858265  -0.691280 -0.873607
# gk_positioning             -0.867845  -0.886930  -0.714367 -0.902784
# attacking_crossing          0.892347   0.855508   0.540605  0.629771
# attacking_finishing         0.741662   0.797187   0.158075  0.529996
# attacking_heading_accuracy  0.680452   0.668213   0.709194  0.869239
# attacking_short_passing     0.941221   0.880296   0.672911  0.762072
# attacking_volleys           0.764127   0.790728   0.241682  0.556889
# skill_dribbling             0.918888   0.970050   0.472632  0.695300
# skill_curve                 0.848557   0.825756   0.393530  0.567297
# skill_fk_accuracy           0.799915   0.745783   0.390623  0.527614
# skill_long_passing          0.856497   0.745113   0.665387  0.642981
# skill_ball_control          0.948878   0.963482   0.581684  0.774722
# movement_acceleration       0.657028   0.744851   0.292401  0.497601
# movement_sprint_speed       0.644566   0.730042   0.312114  0.533033
# movement_agility            0.687435   0.758091   0.259848  0.437086
# movement_reactions          0.392767   0.342117   0.297036  0.287623
# movement_balance            0.617170   0.673673   0.260839  0.350714
# power_shot_power            0.563262   0.547665   0.124780  0.359788
# power_jumping               0.180161   0.186373   0.312069  0.369325
# power_stamina               0.760960   0.746554   0.683393  0.823451
# power_strength              0.093595   0.037022   0.345783  0.474825
# power_long_shots            0.818586   0.822252   0.328314  0.594778
# mentality_aggression        0.616535   0.547671   0.799595  0.800486
# mentality_interceptions     0.523686   0.406146   0.935934  0.649786
# mentality_positioning       0.843869   0.884508   0.337014  0.637760
# mentality_vision            0.710401   0.660792   0.230974  0.365295
# mentality_penalties         0.750132   0.772898   0.277510  0.587084
# mentality_composure         0.670503   0.624338   0.458917  0.549598
# defending_marking           0.560453   0.456071   0.948057  0.685789
# defending_standing_tackle   0.537040   0.425540   0.960212  0.670076
# defending_sliding_tackle    0.506583   0.396908   0.944267  0.639221
# goalkeeping_diving         -0.851647  -0.872002  -0.699265 -0.885002
# goalkeeping_handling       -0.850091  -0.870604  -0.699565 -0.884183
# goalkeeping_kicking        -0.847924  -0.868247  -0.697801 -0.881550
# goalkeeping_positioning    -0.847544  -0.868303  -0.695996 -0.880390
# goalkeeping_reflexes       -0.851474  -0.872033  -0.701089 -0.885241
#
#                             gk_diving  gk_handling  ...  mentality_penalties  \
# weight_kg                    0.334362     0.335248  ...            -0.240796
# player_positions            -0.079968    -0.080001  ...             0.477007
# pace                        -0.886825    -0.887201  ...             0.646803
# shooting                    -0.771024    -0.771351  ...             0.878666
# passing                     -0.869715    -0.870083  ...             0.750132
# dribbling                   -0.888840    -0.889217  ...             0.772898
# defending                   -0.715906    -0.716210  ...             0.277510
# physic                      -0.904729    -0.905112  ...             0.587084
# gk_diving                    1.000000     0.997628  ...            -0.637330
# gk_handling                  0.997628     1.000000  ...            -0.638477
# gk_kicking                   0.995926     0.996051  ...            -0.637601
# gk_reflexes                  0.998657     0.997331  ...            -0.636720
# gk_speed                     0.967175     0.964954  ...            -0.604707
# gk_positioning               0.997322     0.997717  ...            -0.635705
# attacking_crossing          -0.679013    -0.679208  ...             0.653134
# attacking_finishing         -0.603682    -0.604323  ...             0.846443
# attacking_heading_accuracy  -0.765150    -0.765554  ...             0.566056
# attacking_short_passing     -0.750921    -0.752116  ...             0.686323
# attacking_volleys           -0.605947    -0.606427  ...             0.838655
# skill_dribbling             -0.773824    -0.774491  ...             0.775974
# skill_curve                 -0.620625    -0.620752  ...             0.757808
# skill_fk_accuracy           -0.570335    -0.570518  ...             0.739095
# skill_long_passing          -0.610325    -0.610745  ...             0.553250
# skill_ball_control          -0.806261    -0.807077  ...             0.776928
# movement_acceleration       -0.606516    -0.609139  ...             0.535105
# movement_sprint_speed       -0.613150    -0.615459  ...             0.523115
# movement_agility            -0.547183    -0.548974  ...             0.569334
# movement_reactions          -0.085841    -0.089193  ...             0.362505
# movement_balance            -0.518858    -0.520884  ...             0.485702
# power_shot_power            -0.292912    -0.293347  ...             0.670487
# power_jumping               -0.204309    -0.206871  ...             0.134400
# power_stamina               -0.709250    -0.710534  ...             0.522485
# power_strength              -0.128423    -0.128378  ...             0.081360
# power_long_shots            -0.622695    -0.623383  ...             0.818342
# mentality_aggression        -0.598503    -0.598819  ...             0.353731
# mentality_interceptions     -0.498781    -0.499407  ...             0.115185
# mentality_positioning       -0.697672    -0.698326  ...             0.810723
# mentality_vision            -0.374914    -0.374529  ...             0.634859
# mentality_penalties         -0.637330    -0.638477  ...             1.000000
# mentality_composure         -0.431047    -0.431874  ...             0.586786
# defending_marking           -0.557276    -0.557738  ...             0.158944
# defending_standing_tackle   -0.545595    -0.545996  ...             0.109638
# defending_sliding_tackle    -0.523289    -0.523685  ...             0.073859
# goalkeeping_diving           0.985390     0.982538  ...            -0.622365
# goalkeeping_handling         0.981831     0.984542  ...            -0.620956
# goalkeeping_kicking          0.978424     0.978488  ...            -0.617445
# goalkeeping_positioning      0.980849     0.981233  ...            -0.619666
# goalkeeping_reflexes         0.984613     0.982988  ...            -0.620875
#
#                             mentality_composure  defending_marking  \
# weight_kg                             -0.052880          -0.044587
# player_positions                       0.126238          -0.562247
# pace                                   0.442046           0.405720
# shooting                               0.632141           0.244145
# passing                                0.670503           0.560453
# dribbling                              0.624338           0.456071
# defending                              0.458917           0.948057
# physic                                 0.549598           0.685789
# gk_diving                             -0.431047          -0.557276
# gk_handling                           -0.431874          -0.557738
# gk_kicking                            -0.432186          -0.556996
# gk_reflexes                           -0.429504          -0.556712
# gk_speed                              -0.396487          -0.533745
# gk_positioning                        -0.425590          -0.555304
# attacking_crossing                     0.599303           0.449985
# attacking_finishing                    0.568345           0.035383
# attacking_heading_accuracy             0.539620           0.587662
# attacking_short_passing                0.718707           0.578707
# attacking_volleys                      0.620832           0.126654
# skill_dribbling                        0.632588           0.349122
# skill_curve                            0.641454           0.299628
# skill_fk_accuracy                      0.604051           0.305786
# skill_long_passing                     0.673658           0.604378
# skill_ball_control                     0.707705           0.463748
# movement_acceleration                  0.373182           0.193464
# movement_sprint_speed                  0.376365           0.211420
# movement_agility                       0.456677           0.176819
# movement_reactions                     0.696864           0.319493
# movement_balance                       0.343138           0.185746
# power_shot_power                       0.617478           0.072284
# power_jumping                          0.260019           0.293493
# power_stamina                          0.550635           0.598312
# power_strength                         0.289338           0.342057
# power_long_shots                       0.646017           0.222921
# mentality_aggression                   0.541607           0.736695
# mentality_interceptions                0.411502           0.907285
# mentality_positioning                  0.611960           0.211864
# mentality_vision                       0.650873           0.180681
# mentality_penalties                    0.586786           0.158944
# mentality_composure                    1.000000           0.419921
# defending_marking                      0.419921           1.000000
# defending_standing_tackle              0.371679           0.918516
# defending_sliding_tackle               0.336327           0.909029
# goalkeeping_diving                    -0.413275          -0.542540
# goalkeeping_handling                  -0.411964          -0.543464
# goalkeeping_kicking                   -0.409765          -0.540986
# goalkeeping_positioning               -0.405179          -0.538866
# goalkeeping_reflexes                  -0.411598          -0.544195
#
#                             defending_standing_tackle  \
# weight_kg                                   -0.048530
# player_positions                            -0.604224
# pace                                         0.383535
# shooting                                     0.197982
# passing                                      0.537040
# dribbling                                    0.425540
# defending                                    0.960212
# physic                                       0.670076
# gk_diving                                   -0.545595
# gk_handling                                 -0.545996
# gk_kicking                                  -0.545511
# gk_reflexes                                 -0.545316
# gk_speed                                    -0.523774
# gk_positioning                              -0.544346
# attacking_crossing                           0.430614
# attacking_finishing                         -0.018602
# attacking_heading_accuracy                   0.562545
# attacking_short_passing                      0.553168
# attacking_volleys                            0.079004
# skill_dribbling                              0.316053
# skill_curve                                  0.266288
# skill_fk_accuracy                            0.280764
# skill_long_passing                           0.592368
# skill_ball_control                           0.426326
# movement_acceleration                        0.166300
# movement_sprint_speed                        0.184464
# movement_agility                             0.139366
# movement_reactions                           0.270190
# movement_balance                             0.165662
# power_shot_power                             0.023276
# power_jumping                                0.271422
# power_stamina                                0.576511
# power_strength                               0.326172
# power_long_shots                             0.177182
# mentality_aggression                         0.743212
# mentality_interceptions                      0.945395
# mentality_positioning                        0.169291
# mentality_vision                             0.141423
# mentality_penalties                          0.109638
# mentality_composure                          0.371679
# defending_marking                            0.918516
# defending_standing_tackle                    1.000000
# defending_sliding_tackle                     0.975810
# goalkeeping_diving                          -0.531552
# goalkeeping_handling                        -0.532272
# goalkeeping_kicking                         -0.531784
# goalkeeping_positioning                     -0.528839
# goalkeeping_reflexes                        -0.533848
#
#                             defending_sliding_tackle  goalkeeping_diving  \
# weight_kg                                  -0.059735            0.333798
# player_positions                           -0.632534           -0.082184
# pace                                        0.367141           -0.871413
# shooting                                    0.158974           -0.754964
# passing                                     0.506583           -0.851647
# dribbling                                   0.396908           -0.872002
# defending                                   0.944267           -0.699265
# physic                                      0.639221           -0.885002
# gk_diving                                  -0.523289            0.985390
# gk_handling                                -0.523685            0.982538
# gk_kicking                                 -0.523066            0.980712
# gk_reflexes                                -0.522976            0.983935
# gk_speed                                   -0.501719            0.953335
# gk_positioning                             -0.522089            0.982654
# attacking_crossing                          0.411499           -0.662489
# attacking_finishing                        -0.057817           -0.590256
# attacking_heading_accuracy                  0.535258           -0.747442
# attacking_short_passing                     0.520093           -0.733283
# attacking_volleys                           0.039848           -0.592501
# skill_dribbling                             0.287647           -0.758586
# skill_curve                                 0.236366           -0.607078
# skill_fk_accuracy                           0.249123           -0.556401
# skill_long_passing                          0.568389           -0.594074
# skill_ball_control                          0.393085           -0.788940
# movement_acceleration                       0.159107           -0.593664
# movement_sprint_speed                       0.176163           -0.599857
# movement_agility                            0.125265           -0.532946
# movement_reactions                          0.242331           -0.069792
# movement_balance                            0.162013           -0.509398
# power_shot_power                           -0.011656           -0.279877
# power_jumping                               0.269837           -0.193499
# power_stamina                               0.549813           -0.690381
# power_strength                              0.297952           -0.117102
# power_long_shots                            0.138298           -0.607914
# mentality_aggression                        0.720922           -0.580788
# mentality_interceptions                     0.933919           -0.483735
# mentality_positioning                       0.134481           -0.682378
# mentality_vision                            0.107689           -0.362331
# mentality_penalties                         0.073859           -0.622365
# mentality_composure                         0.336327           -0.413275
# defending_marking                           0.909029           -0.542540
# defending_standing_tackle                   0.975810           -0.531552
# defending_sliding_tackle                    1.000000           -0.510298
# goalkeeping_diving                         -0.510298            1.000000
# goalkeeping_handling                       -0.511127            0.970903
# goalkeeping_kicking                        -0.510116            0.966940
# goalkeeping_positioning                    -0.507434            0.970788
# goalkeeping_reflexes                       -0.512319            0.973539
#
#                             goalkeeping_handling  goalkeeping_kicking  \
# weight_kg                               0.335592             0.332756
# player_positions                       -0.079739            -0.078098
# pace                                   -0.871372            -0.868490
# shooting                               -0.753297            -0.750020
# passing                                -0.850091            -0.847924
# dribbling                              -0.870604            -0.868247
# defending                              -0.699565            -0.697801
# physic                                 -0.884183            -0.881550
# gk_diving                               0.981831             0.978424
# gk_handling                             0.984542             0.978488
# gk_kicking                              0.980063             0.983324
# gk_reflexes                             0.981602             0.978238
# gk_speed                                0.949992             0.948006
# gk_positioning                          0.982350             0.978158
# attacking_crossing                     -0.661091            -0.660170
# attacking_finishing                    -0.588582            -0.585544
# attacking_heading_accuracy             -0.746726            -0.743422
# attacking_short_passing                -0.732578            -0.729127
# attacking_volleys                      -0.590768            -0.587198
# skill_dribbling                        -0.756994            -0.754385
# skill_curve                            -0.603900            -0.601945
# skill_fk_accuracy                      -0.553516            -0.550365
# skill_long_passing                     -0.593431            -0.589332
# skill_ball_control                     -0.787934            -0.784674
# movement_acceleration                  -0.596168            -0.593561
# movement_sprint_speed                  -0.602778            -0.599636
# movement_agility                       -0.534953            -0.533810
# movement_reactions                     -0.070526            -0.073305
# movement_balance                       -0.511402            -0.509565
# power_shot_power                       -0.280014            -0.271114
# power_jumping                          -0.195511            -0.196153
# power_stamina                          -0.690648            -0.687042
# power_strength                         -0.115647            -0.117002
# power_long_shots                       -0.606197            -0.602662
# mentality_aggression                   -0.580317            -0.577395
# mentality_interceptions                -0.484468            -0.483437
# mentality_positioning                  -0.680941            -0.677989
# mentality_vision                       -0.358384            -0.355392
# mentality_penalties                    -0.620956            -0.617445
# mentality_composure                    -0.411964            -0.409765
# defending_marking                      -0.543464            -0.540986
# defending_standing_tackle              -0.532272            -0.531784
# defending_sliding_tackle               -0.511127            -0.510116
# goalkeeping_diving                      0.970903             0.966940
# goalkeeping_handling                    1.000000             0.966299
# goalkeeping_kicking                     0.966299             1.000000
# goalkeeping_positioning                 0.970072             0.965839
# goalkeeping_reflexes                    0.970871             0.967781
#
#                             goalkeeping_positioning  goalkeeping_reflexes
# weight_kg                                  0.336227              0.334653
# player_positions                          -0.080493             -0.078148
# pace                                      -0.870095             -0.872499
# shooting                                  -0.750573             -0.753531
# passing                                   -0.847544             -0.851474
# dribbling                                 -0.868303             -0.872033
# defending                                 -0.695996             -0.701089
# physic                                    -0.880390             -0.885241
# gk_diving                                  0.980849              0.984613
# gk_handling                                0.981233              0.982988
# gk_kicking                                 0.978611              0.981202
# gk_reflexes                                0.980974              0.986295
# gk_speed                                   0.951242              0.954267
# gk_positioning                             0.984407              0.983449
# attacking_crossing                        -0.660970             -0.662953
# attacking_finishing                       -0.586318             -0.588179
# attacking_heading_accuracy                -0.742961             -0.747365
# attacking_short_passing                   -0.728060             -0.732910
# attacking_volleys                         -0.587522             -0.590245
# skill_dribbling                           -0.754542             -0.758231
# skill_curve                               -0.603150             -0.605209
# skill_fk_accuracy                         -0.552760             -0.554296
# skill_long_passing                        -0.588603             -0.593829
# skill_ball_control                        -0.784140             -0.788362
# movement_acceleration                     -0.593562             -0.594737
# movement_sprint_speed                     -0.599318             -0.600753
# movement_agility                          -0.532299             -0.534068
# movement_reactions                        -0.063414             -0.067762
# movement_balance                          -0.508401             -0.510859
# power_shot_power                          -0.274518             -0.279526
# power_jumping                             -0.190538             -0.193871
# power_stamina                             -0.687075             -0.690935
# power_strength                            -0.109991             -0.115429
# power_long_shots                          -0.601749             -0.605313
# mentality_aggression                      -0.576149             -0.581314
# mentality_interceptions                   -0.480387             -0.485844
# mentality_positioning                     -0.678541             -0.680904
# mentality_vision                          -0.355272             -0.360150
# mentality_penalties                       -0.619666             -0.620875
# mentality_composure                       -0.405179             -0.411598
# defending_marking                         -0.538866             -0.544195
# defending_standing_tackle                 -0.528839             -0.533848
# defending_sliding_tackle                  -0.507434             -0.512319
# goalkeeping_diving                         0.970788              0.973539
# goalkeeping_handling                       0.970072              0.970871
# goalkeeping_kicking                        0.965839              0.967781
# goalkeeping_positioning                    1.000000              0.970666
# goalkeeping_reflexes                       0.970666              1.000000
#
# [48 rows x 48 columns]

# %%
# построим тепловую карту
fig, ax = plt.subplots()

c = ax.imshow(corr_matr, cmap='RdBu', interpolation='nearest', aspect='auto')
fig.colorbar(c, ax = ax)
fig.set_figwidth(6)
fig.set_figheight(5)

plt.show()

# %%
# определим коррелирующие между собой признаки
corr_features = set()
for i in range(len(corr_matr.columns)): 
    for j in range(i): 
        if abs(corr_matr.iloc[i, j]) > limit_val:
            colname = corr_matr.columns[i]
            corr_features.add(colname)
            
print(corr_features)
# Out:
# {'goalkeeping_reflexes', 'attacking_volleys', 'movement_sprint_speed', 'goalkeeping_handling', 'gk_positioning', 'attacking_short_passing', 'mentality_interceptions', 'skill_ball_control', 'goalkeeping_positioning', 'attacking_finishing', 'mentality_positioning', 'goalkeeping_kicking', 'defending_sliding_tackle', 'gk_reflexes', 'skill_dribbling', 'gk_diving', 'defending_marking', 'gk_kicking', 'gk_handling', 'defending_standing_tackle', 'dribbling', 'gk_speed', 'goalkeeping_diving', 'power_long_shots'}

# %%
# удалим их 
data = data.drop(labels=corr_features, axis=1)

# %% [markdown]
# ### Обучающая и тестовая выборки

# %%
y = data[pos]
data.drop(pos, axis=1)

x = data

# %% [markdown]
# #### Нормализация количественных признаков

# %%
x_std = (x - x.mean(axis=0)) / x.std(axis=0)
x_std.describe()
# Out:
#           weight_kg  player_positions          pace      shooting  \
# count  1.808200e+04      1.808200e+04  1.808200e+04  1.808200e+04
# mean  -5.532818e-16     -3.772376e-17  1.257459e-16  1.760442e-16
# std    1.000000e+00      1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.393435e+00     -1.079801e+00 -2.544942e+00 -2.212626e+00
# 25%   -7.732941e-01     -1.079801e+00 -1.381241e-01 -5.490664e-01
# 50%   -3.686619e-02     -2.294848e-01  2.841247e-01  2.589482e-01
# 75%    6.995617e-01      6.208317e-01  5.796989e-01  7.342509e-01
# max    2.761560e+00      1.471148e+00  1.508646e+00  2.207689e+00
#
#             passing     defending        physic  attacking_crossing  \
# count  1.808200e+04  1.808200e+04  1.808200e+04        1.808200e+04
# mean   1.886188e-16 -4.401105e-17  1.131713e-16        1.760442e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00        1.000000e+00
# min   -2.495840e+00 -2.054452e+00 -2.596320e+00       -2.450863e+00
# 25%   -2.428432e-01 -6.678779e-01 -1.252588e-01       -6.458838e-01
# 50%    2.469387e-01  3.161424e-01  3.240251e-01        2.292576e-01
# 75%    6.387641e-01  8.081525e-01  5.935955e-01        7.762209e-01
# max    2.010153e+00  1.971086e+00  1.447235e+00        2.362415e+00
#
#        attacking_heading_accuracy   skill_curve  ...  movement_reactions  \
# count                1.808200e+04  1.808200e+04  ...        18082.000000
# mean                 7.544752e-17  1.131713e-16  ...            0.000000
# std                  1.000000e+00  1.000000e+00  ...            1.000000
# min                 -2.726146e+00 -2.249605e+00  ...           -4.464005
# 25%                 -4.208784e-01 -7.278612e-01  ...           -0.630834
# 50%                  2.130703e-01  8.735897e-02  ...            0.026280
# 75%                  6.741239e-01  7.938831e-01  ...            0.683395
# max                  2.345443e+00  2.533019e+00  ...            3.749932
#
#        movement_balance  power_shot_power  power_jumping  power_stamina  \
# count      1.808200e+04      1.808200e+04   1.808200e+04   1.808200e+04
# mean       2.514917e-17      2.011934e-16  -4.401105e-17   1.634696e-16
# std        1.000000e+00      1.000000e+00   1.000000e+00   1.000000e+00
# min       -3.690479e+00     -3.315086e+00  -3.864545e+00  -3.191892e+00
# 25%       -5.611130e-01     -7.648846e-01  -5.867510e-01  -4.366927e-01
# 50%        1.501066e-01      6.018063e-02   8.561704e-02   1.894891e-01
# 75%        7.190822e-01      7.352340e-01   6.739390e-01   6.904345e-01
# max        2.354887e+00      2.760394e+00   2.522951e+00   2.130652e+00
#
#        power_strength  mentality_aggression  mentality_vision  \
# count    1.808200e+04          1.808200e+04      1.808200e+04
# mean     5.029835e-17          2.514917e-17      1.005967e-16
# std      1.000000e+00          1.000000e+00      1.000000e+00
# min     -3.649901e+00         -2.708323e+00     -3.199759e+00
# 25%     -5.854931e-01         -6.831677e-01     -6.912594e-01
# 50%      5.964553e-02          1.268942e-01      9.712622e-02
# 75%      7.047841e-01          7.633714e-01      7.421690e-01
# max      2.398273e+00          2.267772e+00      2.892311e+00
#
#        mentality_penalties  mentality_composure
# count         1.808200e+04         1.808200e+04
# mean         -8.802211e-17         2.514917e-17
# std           1.000000e+00         1.000000e+00
# min          -2.642529e+00        -3.923901e+00
# 25%          -6.013993e-01        -6.367733e-01
# 50%           3.645379e-02         1.217947e-01
# 75%           7.380922e-01         7.117920e-01
# max           2.779222e+00         3.156067e+00
#
# [8 rows x 24 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_std, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# ### KNN и получившиеся оценки

# %%
kn_clf_5  = KNeighborsClassifier(n_neighbors=5)
kn_clf_10 = KNeighborsClassifier(n_neighbors=10)
kn_clf_15 = KNeighborsClassifier(n_neighbors=15)

kn_clf_5.fit(x_train.values, y_train.values)
kn_clf_10.fit(x_train.values, y_train.values)
kn_clf_15.fit(x_train.values, y_train.values)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
y_pred_test_5  = kn_clf_5.predict(x_test.values)
y_pred_test_10 = kn_clf_10.predict(x_test.values)
y_pred_test_15 = kn_clf_15.predict(x_test.values)

y_pred_train_5  = kn_clf_5.predict(x_train.values)
y_pred_train_10 = kn_clf_10.predict(x_train.values)
y_pred_train_15 = kn_clf_15.predict(x_train.values)

# %%
print("f1_score for 5 neighbors  test = ", f1_score(y_test.values, y_pred_test_5,  average='macro'))
print("f1_score for 10 neighbors test = ", f1_score(y_test.values, y_pred_test_10, average='macro'))
print("f1_score for 15 neighbors test = ", f1_score(y_test.values, y_pred_test_15, average='macro'))
print()
print("f1_score for 5 neighbors  train = ", f1_score(y_train.values, y_pred_train_5,  average='macro'))
print("f1_score for 10 neighbors train = ", f1_score(y_train.values, y_pred_train_10, average='macro'))
print("f1_score for 15 neighbors train = ", f1_score(y_train.values, y_pred_train_15, average='macro'))
# Out:
# f1_score for 5 neighbors  test =  0.9641263709169962
# f1_score for 10 neighbors test =  0.9616679920992239
# f1_score for 15 neighbors test =  0.9613901120678778
#
# f1_score for 5 neighbors  train =  0.9819690133220624
# f1_score for 10 neighbors train =  0.971461031048229
# f1_score for 15 neighbors train =  0.972919061671071

# %% [markdown]
# ### Выводы
# Метод KNN хорошо справился со своей задачей, показав отличные результаты.
# Результаты можно еще больше улучшить, подобрав и настроив гиперпараметры.
# Спасибо за внимание
#
# *Выполнил Сумин Игорь ПМИ группа 381803-1*
